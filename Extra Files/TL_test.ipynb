# %%
import torch
from torch import nn
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from PIL import Image
import pandas as pd
import torchvision.transforms.functional as IFU
import os
from sklearn.model_selection import train_test_split
import zipfile

# Define paths for extraction
zip_path_train = 'content/train_dataset.zip'


extract_path_train = 'content/train_dataset'


# Function to extract a zip file
def extract_zip(zip_path, extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

# Extract train_dataset.zip
extract_zip(zip_path_train, extract_path_train)
print(f"Train dataset extracted to {extract_path_train}")
# Out:
# Train dataset extracted to content/train_dataset

# %%
# Load train.csv
train_csv = pd.read_csv("train.csv")  # Replace with the actual path to your train.csv

# Mappings for converting labels to integers and vice-versa
label_to_int_map = {
    'bright dune': 0,
    'dark dune': 1,
    'spider': 2,
    'impact ejecta': 3,
    'slope streak': 4,
    'swiss cheese': 5,
    'crater': 6,
    'other': 7
}

int_to_label_map = {v:k for k, v in label_to_int_map.items()}
pd.set_option('future.no_silent_downcasting', True)

# Replace labels with integers
labels_int = train_csv['Class'].replace(label_to_int_map).tolist()

# Construct file paths considering nested structure
file_names = train_csv['File Name']
new_file_names = [os.path.join(extract_path_train, 'train_dataset', fname) for fname in file_names]

# %%
# Split into train and test datasets
x_train, x_val, y_train, y_val = train_test_split(new_file_names, labels_int, test_size=0.25, random_state=42)

# Create DataFrames
train_df = pd.DataFrame({'file_path': x_train, 'label': y_train})
val_df = pd.DataFrame({'file_path': x_val, 'label': y_val})

# %%
freq_df = train_df['label'].value_counts()
print(freq_df)

# Separate the DataFrame into different classes based on the label
df0 = train_df[train_df['label'] == 0].copy()
df1 = train_df[train_df['label'] == 1].copy()
df2 = train_df[train_df['label'] == 2].copy()
df3 = train_df[train_df['label'] == 3].copy()
df4 = train_df[train_df['label'] == 4].copy()
df5 = train_df[train_df['label'] == 5].copy()
df6 = train_df[train_df['label'] == 6].copy()
df7 = train_df[train_df['label'] == 7].copy()

# Duplicate and shuffle the data
df0 = pd.concat([df0 for k in range(2)], ignore_index=True).sample(frac=1).reset_index(drop=True)
df1 = pd.concat([df1 for k in range(4)], ignore_index=True).sample(frac=1).reset_index(drop=True)
df2 = pd.concat([df2 for k in range(9)], ignore_index=True).sample(frac=1).reset_index(drop=True)
df3 = pd.concat([df3 for k in range(11)], ignore_index=True).sample(frac=1).reset_index(drop=True)
df4 = pd.concat([df4 for k in range(4)], ignore_index=True).sample(frac=1).reset_index(drop=True)
df5 = pd.concat([df5 for k in range(4)], ignore_index=True).sample(frac=1).reset_index(drop=True)
df6 = pd.concat([df6 for k in range(2)], ignore_index=True).sample(frac=1).reset_index(drop=True)
df7 = pd.concat([df7 for k in range(1)], ignore_index=True).sample(frac=1).reset_index(drop=True)

# Concatenate all the data back into a single DataFrame and shuffle
train_df_all = pd.concat([df0, df1, df2, df3, df4, df5, df6, df7], ignore_index=True).sample(frac=1).reset_index(drop=True)
print(train_df_all['label'].value_counts())

# Define the number of examples to be taken from each class
noel = [650, 375, 350, 350, 750, 475, 1150, 1400]

# Create two new training DataFrames with specific number of examples from each class
train_df_1 = pd.concat([df0[:noel[0]],
                         df1[:noel[1]],
                         df2[:noel[2]],
                         df3[:noel[3]],
                         df4[:noel[4]],
                         df5[:noel[5]],
                         df6[:noel[6]],
                         df7[:noel[7]]], ignore_index=True).sample(frac=1).reset_index(drop=True)

train_df_2 = pd.concat([df0[-noel[0]:],
                         df1[-noel[1]:],
                         df2[-noel[2]:],
                         df3[-noel[3]:],
                         df4[-noel[4]:],
                         df5[-noel[5]:],
                         df6[-noel[6]:],
                         df7[-noel[7]:]], ignore_index=True).sample(frac=1).reset_index(drop=True)

# Print the shapes of the new DataFrames
print(train_df_1.shape, train_df_2.shape)
# Out:
# label
# 7    2735
# 6     782
# 0     454
# 4     260
# 5     169
# 1     166
# 2      47
# 3      37
# Name: count, dtype: int64
# label
# 7    2735
# 6    1564
# 4    1040
# 0     908
# 5     676
# 1     664
# 2     423
# 3     407
# Name: count, dtype: int64
# (5500, 2) (5500, 2)

# %%
'''
Creating a class that will take in the train/test filenames dataframe
as input and import and store images as a tuple: (image tensor, integer label)

'''
# Dataset class for Mars images
class MarsImgDataset(Dataset):
    def __init__(self, img_df, transform=None):
        self.img_df = img_df
        self.transform = transform

    def __len__(self):
        return len(self.img_df)

    def __getitem__(self, idx):
        img_path = self.img_df.iloc[idx, 0]
        label = self.img_df.iloc[idx, 1]

        image = Image.open(img_path)
        if self.transform:
            image = self.transform(image)

        image = IFU.adjust_contrast(image, 1.7)
        
        return image, label

# %%
# Define transformation for images
IMAGE_SIZE = (224, 224)
data_transform = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    # transforms.TrivialAugmentWide(),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x.repeat(3,1,1)),
    # transforms.Normalize((0.5,), (0.5,)),
])

train_dataset_1 = MarsImgDataset(train_df_1, data_transform)
train_dataset_2 = MarsImgDataset(train_df_2, data_transform)
val_dataset = MarsImgDataset(val_df, data_transform)

train_loader_1 = DataLoader(dataset=train_dataset_1, batch_size=16, shuffle=True) # Initialise Training Loader
train_loader_2 = DataLoader(dataset=train_dataset_2, batch_size=16, shuffle=True) # Initialise Training Loader
val_loader = DataLoader(dataset=val_dataset, batch_size=16, shuffle=True) # Initialise Testing Loader

# Get a batch of images from the test loader
images, labels = next(iter(val_loader))

# %%
## Check the dataloaders by plotting the imported images
img, label = next(iter(train_loader_1))
figure, axis = plt.subplots(2,2)

axis[0,0].imshow(img[0].permute(1,2,0), cmap = 'Greys_r')
axis[0,0].set_title(int_to_label_map[label[0].item()])

axis[0,1].imshow(img[1].permute(1,2,0), cmap = 'Greys_r')
axis[0,1].set_title(int_to_label_map[label[1].item()])

axis[1,0].imshow(img[2].permute(1,2,0), cmap = 'Greys_r')
axis[1,0].set_title(int_to_label_map[label[2].item()])

axis[1,1].imshow(img[3].permute(1,2,0))
axis[1,1].set_title(int_to_label_map[label[3].item()])

plt.subplots_adjust(
    left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.4
)

plt.show()

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
import torchvision
model = torchvision.models.vgg16(weights="VGG16_Weights.DEFAULT")

n_inputs = model.classifier[6].in_features
model.classifier[6] = nn.Sequential(
        nn.Linear(n_inputs, 256), nn.ReLU(), nn.Dropout(0.15),
        nn.Linear(256, 8),
)

for params in model.parameters():
    params.requires_grad = False

for params in model.classifier[6].parameters():
    params.requires_grad = True

# parameters
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.classifier[6].parameters(), lr = 0.002)
num_epochs = 5



device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# %%
IMAGE_WIDTH = IMAGE_SIZE[0]
IMAGE_HEIGHT = IMAGE_SIZE[1]
# Install torchinfo if it's not available, import it if it is
try:
    import torchinfo
except:
    # !pip install torchinfo
    import torchinfo

from torchinfo import summary
# do a test pass through of an example input size
summary(model, input_size=[16, 3, IMAGE_WIDTH ,IMAGE_HEIGHT])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VGG                                      [16, 8]                   --
# ├─Sequential: 1-1                        [16, 512, 7, 7]           --
# │    └─Conv2d: 2-1                       [16, 64, 224, 224]        (1,792)
# │    └─ReLU: 2-2                         [16, 64, 224, 224]        --
# │    └─Conv2d: 2-3                       [16, 64, 224, 224]        (36,928)
# │    └─ReLU: 2-4                         [16, 64, 224, 224]        --
# │    └─MaxPool2d: 2-5                    [16, 64, 112, 112]        --
# │    └─Conv2d: 2-6                       [16, 128, 112, 112]       (73,856)
# │    └─ReLU: 2-7                         [16, 128, 112, 112]       --
# │    └─Conv2d: 2-8                       [16, 128, 112, 112]       (147,584)
# │    └─ReLU: 2-9                         [16, 128, 112, 112]       --
# │    └─MaxPool2d: 2-10                   [16, 128, 56, 56]         --
# │    └─Conv2d: 2-11                      [16, 256, 56, 56]         (295,168)
# │    └─ReLU: 2-12                        [16, 256, 56, 56]         --
# │    └─Conv2d: 2-13                      [16, 256, 56, 56]         (590,080)
# │    └─ReLU: 2-14                        [16, 256, 56, 56]         --
# │    └─Conv2d: 2-15                      [16, 256, 56, 56]         (590,080)
# │    └─ReLU: 2-16                        [16, 256, 56, 56]         --
# │    └─MaxPool2d: 2-17                   [16, 256, 28, 28]         --
# │    └─Conv2d: 2-18                      [16, 512, 28, 28]         (1,180,160)
# │    └─ReLU: 2-19                        [16, 512, 28, 28]         --
# │    └─Conv2d: 2-20                      [16, 512, 28, 28]         (2,359,808)
# │    └─ReLU: 2-21                        [16, 512, 28, 28]         --
# │    └─Conv2d: 2-22                      [16, 512, 28, 28]         (2,359,808)
# │    └─ReLU: 2-23                        [16, 512, 28, 28]         --
# │    └─MaxPool2d: 2-24                   [16, 512, 14, 14]         --
# │    └─Conv2d: 2-25                      [16, 512, 14, 14]         (2,359,808)
# │    └─ReLU: 2-26                        [16, 512, 14, 14]         --
# │    └─Conv2d: 2-27                      [16, 512, 14, 14]         (2,359,808)
# │    └─ReLU: 2-28                        [16, 512, 14, 14]         --
# │    └─Conv2d: 2-29                      [16, 512, 14, 14]         (2,359,808)
# │    └─ReLU: 2-30                        [16, 512, 14, 14]         --
# │    └─MaxPool2d: 2-31                   [16, 512, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-2                 [16, 512, 7, 7]           --
# ├─Sequential: 1-3                        [16, 8]                   --
# │    └─Linear: 2-32                      [16, 4096]                (102,764,544)
# │    └─ReLU: 2-33                        [16, 4096]                --
# │    └─Dropout: 2-34                     [16, 4096]                --
# │    └─Linear: 2-35                      [16, 4096]                (16,781,312)
# │    └─ReLU: 2-36                        [16, 4096]                --
# │    └─Dropout: 2-37                     [16, 4096]                --
# │    └─Sequential: 2-38                  [16, 8]                   --
# │    │    └─Linear: 3-1                  [16, 256]                 1,048,832
# │    │    └─ReLU: 3-2                    [16, 256]                 --
# │    │    └─Dropout: 3-3                 [16, 256]                 --
# │    │    └─Linear: 3-4                  [16, 8]                   2,056
# ==========================================================================================
# Total params: 135,311,432
# Trainable params: 1,050,888
# Non-trainable params: 134,260,544
# Total mult-adds (Units.GIGABYTES): 247.69
# ==========================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 1735.16
# Params size (MB): 541.25
# Estimated Total Size (MB): 2286.04
# ==========================================================================================

# %%
load = False #### SET TO TRUE IF YOU HAVE A PRESAVED CHECKPOINT
if load:
    checkpoint = torch.load("VGG16.pt")
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['opt_state_dict'])
    results = checkpoint['results']
    done_epochs = checkpoint['epoch']
else:
    results = None
    done_epochs = 0

done_epochs
# Out:
# 0

# %%
# 1. Get a batch of images and labels from the DataLoader
img_batch, label_batch = next(iter(train_loader_1))

# 2. Get a single image from the batch and unsqueeze the image so its shape fits the model
img_single, label_single = img_batch[0].unsqueeze(dim=0), label_batch[0]
print(f"Single image shape: {img_single.shape}\n")

# 3. Perform a forward pass on a single image
model.eval()
with torch.inference_mode():
    pred = model(img_single.to(device))

# 4. Print out what's happening and convert model logits -> pred probs -> pred label
print(f"Output logits:\n{pred}\n")
print(f"Output prediction probabilities:\n{torch.softmax(pred, dim=1)}\n")
print(f"Output prediction label:\n{torch.argmax(torch.softmax(pred, dim=1), dim=1).item()}\n")
print(f"Actual label:\n{label_single}")
# Out:
# Single image shape: torch.Size([1, 3, 224, 224])
#
# Output logits:
# tensor([[-0.0040,  0.0616, -0.1159, -0.0093,  0.0268,  0.0704,  0.0540,  0.1441]],
#        device='cuda:0')
#
# Output prediction probabilities:
# tensor([[0.1207, 0.1289, 0.1079, 0.1201, 0.1245, 0.1300, 0.1279, 0.1400]],
#        device='cuda:0')
#
# Output prediction label:
# 7
#
# Actual label:
# 0

# %%
# !pip install torchmetrics
from torchmetrics import ConfusionMatrix, Precision, Recall, F1Score
# Out:
# Requirement already satisfied: torchmetrics in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (1.4.0.post0)
# Requirement already satisfied: numpy>1.20.0 in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (from torchmetrics) (24.0)
# Requirement already satisfied: torch>=1.10.0 in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (from torchmetrics) (2.3.0+cu121)
# Requirement already satisfied: lightning-utilities>=0.8.0 in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (from torchmetrics) (0.11.5)
# Requirement already satisfied: setuptools in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (70.0.0)
# Requirement already satisfied: typing-extensions in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.0)
# Requirement already satisfied: filelock in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.10.0->torchmetrics) (3.14.0)
# Requirement already satisfied: sympy in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.10.0->torchmetrics) (1.12)
# Requirement already satisfied: networkx in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.10.0->torchmetrics) (3.3)
# Requirement already satisfied: jinja2 in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.10.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.10.0->torchmetrics) (2024.5.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.10.0->torchmetrics) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.10.0->torchmetrics) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.10.0->torchmetrics) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=1.10.0->torchmetrics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\mann maru\appdata\local\programs\python\python312\lib\site-packages (from sympy->torch>=1.10.0->torchmetrics) (1.3.0)

# %%
from torchmetrics import ConfusionMatrix, Precision, Recall, F1Score

def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

     # Define metrics
    precision = Precision(average='macro', num_classes=8, task='MULTICLASS').to(device)
    recall = Recall(average='macro', num_classes=8, task='MULTICLASS').to(device)
    f1 = F1Score(average='macro', num_classes=8, task='MULTICLASS').to(device)

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        # print(loss.item())
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metric across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

        # Update metrics
        # print(y.shape, y_pred_class.shape)
        precision.update(y_pred_class, y)
        recall.update(y_pred_class, y)
        f1.update(y_pred_class, y)


    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)

    # Compute precision, recall, f1 score, and confusion matrix
    train_precision = precision.compute().item()
    train_recall = recall.compute().item()
    train_f1 = f1.compute().item()


    return train_loss, train_acc, train_precision, train_recall, train_f1

# %%
def val_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):
    # Put model in eval mode
    model.eval()

    # Setup test loss and test accuracy values
    val_loss, val_acc = 0, 0

    # Define metrics
    precision = Precision(average='macro', num_classes=8, task='MULTICLASS').to(device)
    recall = Recall(average='macro', num_classes=8, task='MULTICLASS').to(device)
    f1 = F1Score(average='macro', num_classes=8, task='MULTICLASS').to(device)

    # Turn on inference context manager
    with torch.inference_mode():
        # Loop through DataLoader batches
        for batch, (X, y) in enumerate(dataloader):
            # Send data to target device
            X, y = X.to(device), y.to(device)

            # 1. Forward pass
            val_pred_logits = model(X)

            # 2. Calculate and accumulate loss
            loss = loss_fn(val_pred_logits, y)
            val_loss += loss.item()

            # Calculate and accumulate accuracy
            val_pred_labels = val_pred_logits.argmax(dim=1)
            val_acc += ((val_pred_labels == y).sum().item()/len(val_pred_labels))

            precision.update(val_pred_labels, y)
            recall.update(val_pred_labels, y)
            f1.update(val_pred_labels, y)




    # Adjust metrics to get average loss and accuracy per batch
    val_loss = val_loss / len(dataloader)
    val_acc = val_acc / len(dataloader)

     # Compute precision, recall, f1 score, and confusion matrix
    val_precision = precision.compute().item()
    val_recall = recall.compute().item()
    val_f1 = f1.compute().item()


    return val_loss, val_acc, val_precision, val_recall, val_f1

# %%
# Define the train function
from tqdm.auto import tqdm
def train(model: torch.nn.Module,
          train_dataloader_1: torch.utils.data.DataLoader,
          train_dataloader_2: torch.utils.data.DataLoader,
          val_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int = 5,
          results = None,
          done_epochs = 0):
    # Create empty results dictionary
    if results == None:
        results = {
            "train_loss": [],
            "train_acc": [],
            "train_precision": [],
            "train_recall": [],
            "train_f1": [],

            "val_loss": [],
            "val_acc": [],
            "val_precision": [],
            "val_recall": [],
            "val_f1": []}


    # Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        if epoch%2 == 0:
            train_dataloader = train_dataloader_1
        else:
            train_dataloader = train_dataloader_2

        train_loss, train_acc, train_precision, train_recall, train_f1 = train_step(
            model=model,
            dataloader=train_dataloader,
            loss_fn=loss_fn,
            optimizer=optimizer)

        val_loss, val_acc, val_precision, val_recall, val_f1 = val_step(
            model=model,
            dataloader=val_dataloader,
            loss_fn=loss_fn)

        # Print out what's happening
        print(
            f"Epoch: {epoch+done_epochs+2} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"train_precision: {train_precision:.4f} | "
            f"train_recall: {train_recall:.4f} | "
            f"train_f1: {train_f1:.4f} | "
            f"val_loss: {val_loss:.4f} | "
            f"val_acc: {val_acc:.4f} | "
            f"val_precision: {val_precision:.4f} | "
            f"val_recall: {val_recall:.4f} | "
            f"val_f1: {val_f1:.4f}"
        )

        # Update results dictionary
        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["train_precision"].append(train_precision)
        results["train_recall"].append(train_recall)
        results["train_f1"].append(train_f1)
        results["val_loss"].append(val_loss)
        results["val_acc"].append(val_acc)
        results["val_precision"].append(val_precision)
        results["val_recall"].append(val_recall)
        results["val_f1"].append(val_f1)

        torch.save({
                    'model_state_dict':model.state_dict(),
                    'opt_state_dict': optimizer.state_dict(),
                    'results':results,
                    'epoch':epoch + done_epochs + 1
                }, "VGG16_2.pt")

    # Return the filled results at the end of the epochs
    return results

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Set number of epochs
NUM_EPOCHS = 50

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_0
model_results = train(model=model,
                      train_dataloader_1=train_loader_1,
                      train_dataloader_2=train_loader_2,
                      val_dataloader=val_loader,
                      optimizer=optimizer,
                      loss_fn=criterion,
                      epochs=NUM_EPOCHS,
                      results=results,
                      done_epochs=done_epochs)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch: 2 | train_loss: 0.6890 | train_acc: 0.7447 | train_precision: 0.7704 | train_recall: 0.7374 | train_f1: 0.7508 | val_loss: 0.5241 | val_acc: 0.8233 | val_precision: 0.7243 | val_recall: 0.8811 | val_f1: 0.7846
# Epoch: 3 | train_loss: 0.4655 | train_acc: 0.8192 | train_precision: 0.8485 | train_recall: 0.8455 | train_f1: 0.8468 | val_loss: 0.5307 | val_acc: 0.7518 | val_precision: 0.8113 | val_recall: 0.8343 | val_f1: 0.8001
# Epoch: 4 | train_loss: 0.4271 | train_acc: 0.8421 | train_precision: 0.8700 | train_recall: 0.8637 | train_f1: 0.8667 | val_loss: 0.4245 | val_acc: 0.8420 | val_precision: 0.7800 | val_recall: 0.8887 | val_f1: 0.8156
# Epoch: 5 | train_loss: 0.3892 | train_acc: 0.8521 | train_precision: 0.8784 | train_recall: 0.8769 | train_f1: 0.8776 | val_loss: 0.3620 | val_acc: 0.8736 | val_precision: 0.8692 | val_recall: 0.8668 | val_f1: 0.8660
# Epoch: 6 | train_loss: 0.3650 | train_acc: 0.8601 | train_precision: 0.8931 | train_recall: 0.8850 | train_f1: 0.8889 | val_loss: 0.3636 | val_acc: 0.8717 | val_precision: 0.7914 | val_recall: 0.8811 | val_f1: 0.8214
# Epoch: 7 | train_loss: 0.3651 | train_acc: 0.8602 | train_precision: 0.8849 | train_recall: 0.8873 | train_f1: 0.8861 | val_loss: 0.3655 | val_acc: 0.8711 | val_precision: 0.8572 | val_recall: 0.8702 | val_f1: 0.8596
# Epoch: 8 | train_loss: 0.3463 | train_acc: 0.8680 | train_precision: 0.8968 | train_recall: 0.8958 | train_f1: 0.8963 | val_loss: 0.4514 | val_acc: 0.8272 | val_precision: 0.7142 | val_recall: 0.9037 | val_f1: 0.7800
# Epoch: 9 | train_loss: 0.3426 | train_acc: 0.8719 | train_precision: 0.8990 | train_recall: 0.8999 | train_f1: 0.8994 | val_loss: 0.4462 | val_acc: 0.8194 | val_precision: 0.8207 | val_recall: 0.8760 | val_f1: 0.8353
# Epoch: 10 | train_loss: 0.3451 | train_acc: 0.8750 | train_precision: 0.9008 | train_recall: 0.8986 | train_f1: 0.8997 | val_loss: 0.4101 | val_acc: 0.8473 | val_precision: 0.7691 | val_recall: 0.9071 | val_f1: 0.8215
# Epoch: 11 | train_loss: 0.3040 | train_acc: 0.8845 | train_precision: 0.9103 | train_recall: 0.9102 | train_f1: 0.9102 | val_loss: 0.4511 | val_acc: 0.8284 | val_precision: 0.8034 | val_recall: 0.8841 | val_f1: 0.8308
# Epoch: 12 | train_loss: 0.2965 | train_acc: 0.8912 | train_precision: 0.9162 | train_recall: 0.9158 | train_f1: 0.9160 | val_loss: 0.3491 | val_acc: 0.8704 | val_precision: 0.7885 | val_recall: 0.8991 | val_f1: 0.8251
# Epoch: 13 | train_loss: 0.3069 | train_acc: 0.8811 | train_precision: 0.9082 | train_recall: 0.9099 | train_f1: 0.9090 | val_loss: 0.3651 | val_acc: 0.8601 | val_precision: 0.8131 | val_recall: 0.8911 | val_f1: 0.8404
# Epoch: 14 | train_loss: 0.3066 | train_acc: 0.8834 | train_precision: 0.9116 | train_recall: 0.9089 | train_f1: 0.9102 | val_loss: 0.3644 | val_acc: 0.8639 | val_precision: 0.8305 | val_recall: 0.9039 | val_f1: 0.8605
# Epoch: 15 | train_loss: 0.3140 | train_acc: 0.8877 | train_precision: 0.9154 | train_recall: 0.9141 | train_f1: 0.9147 | val_loss: 0.3138 | val_acc: 0.8847 | val_precision: 0.8491 | val_recall: 0.9156 | val_f1: 0.8797
# Epoch: 16 | train_loss: 0.3085 | train_acc: 0.8876 | train_precision: 0.9125 | train_recall: 0.9156 | train_f1: 0.9140 | val_loss: 0.3782 | val_acc: 0.8563 | val_precision: 0.7794 | val_recall: 0.9258 | val_f1: 0.8345
# Epoch: 17 | train_loss: 0.2979 | train_acc: 0.8888 | train_precision: 0.9154 | train_recall: 0.9165 | train_f1: 0.9160 | val_loss: 0.3536 | val_acc: 0.8749 | val_precision: 0.7900 | val_recall: 0.9027 | val_f1: 0.8344
# Epoch: 18 | train_loss: 0.3033 | train_acc: 0.8904 | train_precision: 0.9141 | train_recall: 0.9149 | train_f1: 0.9144 | val_loss: 0.3210 | val_acc: 0.8808 | val_precision: 0.8278 | val_recall: 0.9006 | val_f1: 0.8562
# Epoch: 19 | train_loss: 0.2927 | train_acc: 0.8876 | train_precision: 0.9160 | train_recall: 0.9165 | train_f1: 0.9162 | val_loss: 0.3272 | val_acc: 0.8808 | val_precision: 0.8010 | val_recall: 0.9096 | val_f1: 0.8461
# Epoch: 20 | train_loss: 0.2882 | train_acc: 0.8927 | train_precision: 0.9218 | train_recall: 0.9197 | train_f1: 0.9207 | val_loss: 0.3474 | val_acc: 0.8653 | val_precision: 0.8178 | val_recall: 0.9195 | val_f1: 0.8566
# Epoch: 21 | train_loss: 0.2880 | train_acc: 0.8947 | train_precision: 0.9198 | train_recall: 0.9195 | train_f1: 0.9196 | val_loss: 0.3345 | val_acc: 0.8762 | val_precision: 0.8327 | val_recall: 0.9149 | val_f1: 0.8684
# Epoch: 22 | train_loss: 0.2778 | train_acc: 0.8969 | train_precision: 0.9222 | train_recall: 0.9231 | train_f1: 0.9226 | val_loss: 0.3216 | val_acc: 0.8839 | val_precision: 0.8230 | val_recall: 0.9219 | val_f1: 0.8637
# Epoch: 23 | train_loss: 0.2636 | train_acc: 0.8993 | train_precision: 0.9248 | train_recall: 0.9266 | train_f1: 0.9257 | val_loss: 0.2841 | val_acc: 0.9117 | val_precision: 0.8611 | val_recall: 0.9181 | val_f1: 0.8842
# Epoch: 24 | train_loss: 0.2589 | train_acc: 0.9062 | train_precision: 0.9280 | train_recall: 0.9287 | train_f1: 0.9283 | val_loss: 0.3501 | val_acc: 0.8685 | val_precision: 0.7834 | val_recall: 0.9103 | val_f1: 0.8287
# Epoch: 25 | train_loss: 0.2662 | train_acc: 0.9024 | train_precision: 0.9280 | train_recall: 0.9269 | train_f1: 0.9274 | val_loss: 0.2957 | val_acc: 0.8949 | val_precision: 0.8355 | val_recall: 0.9289 | val_f1: 0.8754
# Epoch: 26 | train_loss: 0.2655 | train_acc: 0.9055 | train_precision: 0.9303 | train_recall: 0.9289 | train_f1: 0.9296 | val_loss: 0.3606 | val_acc: 0.8782 | val_precision: 0.8086 | val_recall: 0.9258 | val_f1: 0.8578
# Epoch: 27 | train_loss: 0.2596 | train_acc: 0.9037 | train_precision: 0.9292 | train_recall: 0.9317 | train_f1: 0.9304 | val_loss: 0.2983 | val_acc: 0.8929 | val_precision: 0.8355 | val_recall: 0.9065 | val_f1: 0.8657
# Epoch: 28 | train_loss: 0.2784 | train_acc: 0.9001 | train_precision: 0.9217 | train_recall: 0.9251 | train_f1: 0.9233 | val_loss: 0.2740 | val_acc: 0.9085 | val_precision: 0.8866 | val_recall: 0.9052 | val_f1: 0.8941
# Epoch: 29 | train_loss: 0.2652 | train_acc: 0.9024 | train_precision: 0.9274 | train_recall: 0.9287 | train_f1: 0.9280 | val_loss: 0.3377 | val_acc: 0.8853 | val_precision: 0.8351 | val_recall: 0.9141 | val_f1: 0.8693
# Epoch: 30 | train_loss: 0.2622 | train_acc: 0.9055 | train_precision: 0.9289 | train_recall: 0.9289 | train_f1: 0.9289 | val_loss: 0.3255 | val_acc: 0.8774 | val_precision: 0.8319 | val_recall: 0.9174 | val_f1: 0.8673
# Epoch: 31 | train_loss: 0.2591 | train_acc: 0.9056 | train_precision: 0.9307 | train_recall: 0.9309 | train_f1: 0.9308 | val_loss: 0.3121 | val_acc: 0.8859 | val_precision: 0.8500 | val_recall: 0.9109 | val_f1: 0.8750
# Epoch: 32 | train_loss: 0.2667 | train_acc: 0.9064 | train_precision: 0.9289 | train_recall: 0.9297 | train_f1: 0.9293 | val_loss: 0.3258 | val_acc: 0.8788 | val_precision: 0.8118 | val_recall: 0.9179 | val_f1: 0.8453
# Epoch: 33 | train_loss: 0.2466 | train_acc: 0.9081 | train_precision: 0.9326 | train_recall: 0.9352 | train_f1: 0.9338 | val_loss: 0.3011 | val_acc: 0.8930 | val_precision: 0.8514 | val_recall: 0.9106 | val_f1: 0.8751
# Epoch: 34 | train_loss: 0.2657 | train_acc: 0.9092 | train_precision: 0.9316 | train_recall: 0.9321 | train_f1: 0.9319 | val_loss: 0.3162 | val_acc: 0.8897 | val_precision: 0.8361 | val_recall: 0.9104 | val_f1: 0.8689
# Epoch: 35 | train_loss: 0.2417 | train_acc: 0.9110 | train_precision: 0.9349 | train_recall: 0.9335 | train_f1: 0.9342 | val_loss: 0.2964 | val_acc: 0.9053 | val_precision: 0.8527 | val_recall: 0.9216 | val_f1: 0.8831
# Epoch: 36 | train_loss: 0.2498 | train_acc: 0.9151 | train_precision: 0.9359 | train_recall: 0.9346 | train_f1: 0.9353 | val_loss: 0.3220 | val_acc: 0.8840 | val_precision: 0.8149 | val_recall: 0.9264 | val_f1: 0.8608
# Epoch: 37 | train_loss: 0.2536 | train_acc: 0.9077 | train_precision: 0.9323 | train_recall: 0.9298 | train_f1: 0.9310 | val_loss: 0.4506 | val_acc: 0.8370 | val_precision: 0.7652 | val_recall: 0.9061 | val_f1: 0.8176
# Epoch: 38 | train_loss: 0.2506 | train_acc: 0.9113 | train_precision: 0.9341 | train_recall: 0.9336 | train_f1: 0.9338 | val_loss: 0.3069 | val_acc: 0.8994 | val_precision: 0.8481 | val_recall: 0.9050 | val_f1: 0.8700
# Epoch: 39 | train_loss: 0.2522 | train_acc: 0.9101 | train_precision: 0.9317 | train_recall: 0.9320 | train_f1: 0.9318 | val_loss: 0.2681 | val_acc: 0.9091 | val_precision: 0.8816 | val_recall: 0.9210 | val_f1: 0.8989
# Epoch: 40 | train_loss: 0.2487 | train_acc: 0.9141 | train_precision: 0.9340 | train_recall: 0.9302 | train_f1: 0.9320 | val_loss: 0.2680 | val_acc: 0.9098 | val_precision: 0.8284 | val_recall: 0.9277 | val_f1: 0.8710
# Epoch: 41 | train_loss: 0.2442 | train_acc: 0.9076 | train_precision: 0.9319 | train_recall: 0.9301 | train_f1: 0.9310 | val_loss: 0.2989 | val_acc: 0.9058 | val_precision: 0.8742 | val_recall: 0.9137 | val_f1: 0.8922
# Epoch: 42 | train_loss: 0.2350 | train_acc: 0.9168 | train_precision: 0.9379 | train_recall: 0.9368 | train_f1: 0.9373 | val_loss: 0.2612 | val_acc: 0.9104 | val_precision: 0.8817 | val_recall: 0.9148 | val_f1: 0.8971
# Epoch: 43 | train_loss: 0.2403 | train_acc: 0.9140 | train_precision: 0.9361 | train_recall: 0.9364 | train_f1: 0.9362 | val_loss: 0.2411 | val_acc: 0.9180 | val_precision: 0.8766 | val_recall: 0.9203 | val_f1: 0.8967
# Epoch: 44 | train_loss: 0.2402 | train_acc: 0.9138 | train_precision: 0.9366 | train_recall: 0.9357 | train_f1: 0.9361 | val_loss: 0.3145 | val_acc: 0.8930 | val_precision: 0.8433 | val_recall: 0.9173 | val_f1: 0.8738
# Epoch: 45 | train_loss: 0.2503 | train_acc: 0.9082 | train_precision: 0.9333 | train_recall: 0.9330 | train_f1: 0.9331 | val_loss: 0.3503 | val_acc: 0.8768 | val_precision: 0.8607 | val_recall: 0.9133 | val_f1: 0.8837
# Epoch: 46 | train_loss: 0.2432 | train_acc: 0.9117 | train_precision: 0.9371 | train_recall: 0.9361 | train_f1: 0.9366 | val_loss: 0.2777 | val_acc: 0.9098 | val_precision: 0.8984 | val_recall: 0.9144 | val_f1: 0.9058
# Epoch: 47 | train_loss: 0.2321 | train_acc: 0.9151 | train_precision: 0.9386 | train_recall: 0.9360 | train_f1: 0.9373 | val_loss: 0.2959 | val_acc: 0.9027 | val_precision: 0.8497 | val_recall: 0.9239 | val_f1: 0.8828
# Epoch: 48 | train_loss: 0.2360 | train_acc: 0.9106 | train_precision: 0.9349 | train_recall: 0.9328 | train_f1: 0.9338 | val_loss: 0.3228 | val_acc: 0.8961 | val_precision: 0.8410 | val_recall: 0.9058 | val_f1: 0.8675
# Epoch: 49 | train_loss: 0.2381 | train_acc: 0.9182 | train_precision: 0.9392 | train_recall: 0.9415 | train_f1: 0.9403 | val_loss: 0.2920 | val_acc: 0.9013 | val_precision: 0.8790 | val_recall: 0.9211 | val_f1: 0.8984
# Epoch: 50 | train_loss: 0.2252 | train_acc: 0.9192 | train_precision: 0.9429 | train_recall: 0.9410 | train_f1: 0.9419 | val_loss: 0.2958 | val_acc: 0.9008 | val_precision: 0.8452 | val_recall: 0.9151 | val_f1: 0.8757
# Epoch: 51 | train_loss: 0.2233 | train_acc: 0.9202 | train_precision: 0.9425 | train_recall: 0.9411 | train_f1: 0.9418 | val_loss: 0.3099 | val_acc: 0.9034 | val_precision: 0.8496 | val_recall: 0.9238 | val_f1: 0.8801
# Total training time: 4108.170 seconds

# %%
def plot_loss_curves(results):

    results = dict(list(results.items()))

    # Get the loss values of the results dictionary (training and test)
    loss = results['train_loss']
    val_loss = results['val_loss']

    # Get the accuracy values of the results dictionary (training and test)
    accuracy = results['train_acc']
    val_accuracy = results['val_acc']

    accuracy = results['train_acc']
    val_accuracy = results['val_acc']

    precision = results['train_precision']
    val_precision = results['val_precision']

    recall = results['train_recall']
    val_recall = results['val_recall']

    f1 = results['train_f1']
    val_f1 = results['val_f1']




    # Figure out how many epochs there were
    epochs = range(len(results['train_loss']))

    # Setup a plot
    plt.figure(figsize=(15, 7))

    # Plot loss
    plt.subplot(2, 3, 1)
    plt.plot(epochs, loss, label='train_loss')
    plt.plot(epochs, val_loss, label='val_loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.legend()
    plt.ylim([0, 1.001])

    # Plot accuracy
    plt.subplot(2, 3, 2)
    plt.plot(epochs, accuracy, label='train_accuracy')
    plt.plot(epochs, val_accuracy, label='val_accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.legend();
    plt.ylim([0, 1.001])

    # Plot precision
    plt.subplot(2, 3, 3)
    plt.plot(epochs, precision, label='train_precision')
    plt.plot(epochs, val_precision, label='val_precision')
    plt.title('Precision')
    plt.xlabel('Epochs')
    plt.legend()
    plt.ylim([0, 1.001])

    # Plot recall
    plt.subplot(2, 3, 4)
    plt.plot(epochs, recall, label='train_recall')
    plt.plot(epochs, val_recall, label='val_recall')
    plt.title('Recall')
    plt.xlabel('Epochs')
    plt.legend();
    plt.ylim([0, 1.001])


    plt.subplot(2, 3, 5)
    plt.plot(epochs, f1, label='train_f1')
    plt.plot(epochs, val_f1, label='val_f1')
    plt.title('F1 Score')
    plt.xlabel('Epochs')
    plt.legend();
    plt.ylim([0, 1.001])

    plt.tight_layout()

# %%
plot_loss_curves(model_results)
